# %%
import warnings
import itertools
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import re
import string
import matplotlib.pyplot as plt
import os

from prefixspan import PrefixSpan


warnings.filterwarnings("ignore")
pd.options.mode.chained_assignment = None
nltk.download('stopwords')
nltk.download('punkt')
factory = StemmerFactory()
stemmer = factory.create_stemmer()
listStopword =  set(stopwords.words('indonesian'))
# Out:
# [nltk_data] Downloading package stopwords to punkt...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
rmlist = ['bengkulu', 'and', 'of', 'on','in','based','the','to','indonesia','thailand','from', 'for','berbasis']

# %%
def read_data(x):
    XL = pd.ExcelFile(os.path.join("data","data_mod.xlsx"))
    sheet = XL.sheet_names[x]
    data = pd.read_excel(XL, sheet)
    if sheet != "LPPM":
        data = data[~data['Topik'].isnull()]
    else:
        data = data[~data['Judul'].isnull()]
    data['Tahun'] = data['Tahun'].astype(int)
    data = data.reset_index(drop=True)
    data = data[data.columns.tolist()[:-3]].join(data[data.columns.tolist()[-2:]]).join(data[data.columns.tolist()[-3]])
    return data, sheet

def preprocessing(data, listtoberemoved):
    # df = pd.DataFrame(data['Judul'] + " " + data['Abstark'] + " " + data['Keyword'],columns=['Judul']).copy()
    # df = pd.DataFrame(data['Judul'] + " " + data['Keyword'],columns=['Judul']).copy()
    # df = pd.DataFrame(data['Judul'] + " " + data['Abstark'],columns=['Judul']).copy()
    df = pd.DataFrame(data['Judul'],columns=['Judul']).copy()
    cleaned = []
    for n in df['Judul'].values:
        n = n.lower()
        n = re.sub(r':', '', n)
        n = re.sub(r'‚Ä¶', '', n)
        n = re.sub(r'[^\x00-\x7F]+',' ', n)
        n = re.sub('[^a-zA-Z]', ' ', n)
        n = re.sub("&lt;/?.*?&gt;","&lt;&gt;",n)
        n = re.sub("(\\d|\\W)+"," ",n)
        n = re.sub(r'â', '', n)
        n = re.sub(r'€', '', n)
        n = re.sub(r'¦', '', n)
        cleaned.append(n)
    df['cleaned'] = cleaned

    tokenized = []
    for n in cleaned:
        n = word_tokenize(n)
        tokenized.append(n)
    df['tokenized'] = [', '.join(n) for n in tokenized]

    removed = []
    for ts in tokenized:
        n = []
        for t in ts:
            if t not in listtoberemoved and t not in listStopword and t not in string.punctuation:
                n.append(t)
        removed.append(n)
    df['removed'] = [', '.join(n) for n in removed]

    stemmed = []
    for n in removed:
        n = ' '.join(n)
        n = stemmer.stem(n)
        n = n.split(' ')
        stemmed.append(n)
    df['stemmed'] = [' '.join(n) for n in stemmed]
    return df, stemmed

def mining(data,stemmed, ms=3, mp=10, mnp=2):
    dx = [n for n in [a + b + c for a,b,c in zip(stemmed,data['Keyword'].str.split(",").values.tolist(),data['Topik'].str.split(",").values.tolist())]]
    print(1)
    ps = PrefixSpan(dx)
    print(2)
    pf_results = pd.DataFrame(ps.frequent(ms), columns=['freq','sequence'])
    print(3)
    pf_results['sequence'] = [', '.join(n) for n in pf_results['sequence'].values.tolist()]
    pf_results = pf_results[[len(n)<=mp for n in pf_results['sequence'].str.split(",").values.tolist()]]
    pf_results = pf_results[[len(n)>=mnp for n in pf_results['sequence'].str.split(",").values.tolist()]].sort_values(by='freq',ascending=False).reset_index(drop=True)

    return pf_results

def run(x,listtoberemoved, ms=3, mp=10, mnp=2):
    data, sheet= read_data(x)
    df, stemmed = preprocessing(data, listtoberemoved)
    pf= mining(data, stemmed, ms=ms, mp=mp, mnp=mnp)
    return sheet, pf,data, df

# %%
sheet, results, data, df = run(6,rmlist)


print(sheet)
results
# Out:
# 1
# 2
# 3
# Sistem Informasi
#      freq                                           sequence
# 0       4                               learning, E-Learning
# 1       3                             scientific, E-Learning
# 2       3                               literacy, E-Learning
# 3       3                   scientific, literacy, E-Learning
# 4       3                               scientific, literacy
# ..    ...                                                ...
# 172     2              mobile, learning, application, school
# 173     2  mobile, learning, application, school,  elemen...
# 174     2  mobile, learning, application,  elementary school
# 175     2                       mobile, learning, elementary
# 176     2                                  mampu, Pendidikan
#
# [177 rows x 2 columns]

# %%
topik = list(set(itertools.chain.from_iterable(data['Topik'].str.split(', ').values.tolist())))
topik
# Out:
# ['Sistem Pendukung Keputusan',
#  'Machine Learning',
#  'Augmented Relaity',
#  'Mobile Development',
#  'Image Processing',
#  'Cybersecurity',
#  'Animation',
#  'Recommendation System',
#  'Data Mining',
#  'Sistem Informasi',
#  'GIS',
#  'E-Learning',
#  'E-Commerce',
#  'Pendidikan',
#  'Technopreneur']

# %%
from collections import Counter

rekomendasi = dict(Counter([n for n in ', '.join(results['sequence'].values.tolist()).split(', ') if n in topik])).keys()
', '.join(rekomendasi)
# Out:
# 'E-Learning, Animation, Pendidikan, Sistem Pendukung Keputusan, Data Mining, GIS, Recommendation System, Image Processing'

# %%
results[[list(rekomendasi)[0] in n for n in results['sequence']]]
# Out:
#      freq                                           sequence
# 0       4                               learning, E-Learning
# 1       3                             scientific, E-Learning
# 2       3                               literacy, E-Learning
# 3       3                   scientific, literacy, E-Learning
# 6       3                                    ict, E-Learning
# 7       2         scientific, literacy, students, E-Learning
# 9       2  scientific, literacy,  scientific literacy, E-...
# 12      2         scientific, elementary, school, E-Learning
# 14      2                 scientific, elementary, E-Learning
# 16      2                     scientific, school, E-Learning
# 19      2  scientific, students,  scientific literacy, E-...
# 20      2                   scientific, students, E-Learning
# 22      2       scientific,  scientific literacy, E-Learning
# 23      2  scientific, literacy, students,  scientific li...
# 26      2                     elementary, school, E-Learning
# 32      2         students,  scientific literacy, E-Learning
# 33      2                               students, E-Learning
# 36      2           scientific, literacy, school, E-Learning
# 37      2                             elementary, E-Learning
# 39      2                                 school, E-Learning
# 42      2  scientific, literacy, elementary, school, E-Le...
# 43      2       scientific, literacy, elementary, E-Learning
# 46      2           literacy, elementary, school, E-Learning
# 59      2                         sekolah, dasar, E-Learning
# 60      2                                sekolah, E-Learning
# 61      2                                  dasar, E-Learning
# 62      2                                   ajar, E-Learning
# 71      2                   literacy, elementary, E-Learning
# 73      2                       literacy, school, E-Learning
# 76      2  literacy, students,  scientific literacy, E-Le...
# 77      2                     literacy, students, E-Learning
# 79      2         literacy,  scientific literacy, E-Learning
# 80      2                                  media, E-Learning
# 81      2                    scientific literacy, E-Learning
# 82      2                              education, E-Learning
# 85      2                        literasi, sains, E-Learning
# 86      2                               literasi, E-Learning
# 87      2                                  sains, E-Learning
# 134     2                                 mobile, E-Learning
# 156     2         learning,  scientific literacy, E-Learning
# 160     2         learning, scientific, literacy, E-Learning
# 161     2                   learning, scientific, E-Learning
# 163     2                     learning, literacy, E-Learning
# 164     2                     E-Learning,  Augmented Relaity

# %%
results.to_csv("prefix_span.csv", index=False)

# %%
df
# Out:
#                                                 Judul  \
# 0   pengenalan steganografi untuk pengamanan infor...
# 1   the analysis of rank fusion techniques to impr...
# 2   improving performance of relation extraction a...
# 3   pemanfaatan citra penginderaan jauh dan sistem...
# 4         social influences in recommendation systems
# 5   cselene: privacy preserving query retrieval sy...
# 6   highly relevant routing recommendation systems...
# 7   prototipe interoperabilitas learning technolog...
# 8   kompresi citra batik besurek menggunakan discr...
# 9   disaster risk reduction for earthquake using m...
# 10  analysis of language and scientific literacy s...
# 11  the effectiveness of turtle mobile learning ap...
# 12  online expert systems for bamboo identificatio...
# 13  image splicing detection based on demosaicking...
# 14  project-based learning to improve scientific l...
# 15  implementasi program literasi sains berbasis i...
# 16  pemetaan zonasi rawan banjir dengan analisis i...
# 17  peningkatan keterampilan guru sd dalam pembuat...
# 18  pengembangan technopreneur produk turunan kopi...
# 19  designing inquiry-based expertise sharing mode...
# 20  literasi sains kura-kura dengan realitas terta...
# 21  penggunaan aplikasi mobile untuk pembelajaran ...
# 22  peningkatan pendidikan kesiapsiagaan bencana s...
# 23  rancang bangun sistem informasi pemantau trans...
# 24  handling numerical features on dataset using g...
# 25  perancangan framework mobile device management...
# 26  mapping teacher distribution analysis with dig...
# 27  pemberdayaan santri pesantren berwawasan keahl...
# 28  implementasi prinsip animasi straight ahead ac...
# 29  deciding endemic area of dengue fever using si...
# 30  sosialisasi pencegahan iklan berkonten negatif...
# 31  pengembangan keterampilan dan kemampuan guru s...
# 32  implementasi metode ahp-topsis dalam sistem pe...
# 33  sistem prediksi masa studi dan predikat kelulu...
#
#                                               cleaned  \
# 0   pengenalan steganografi untuk pengamanan infor...
# 1   the analysis of rank fusion techniques to impr...
# 2   improving performance of relation extraction a...
# 3   pemanfaatan citra penginderaan jauh dan sistem...
# 4         social influences in recommendation systems
# 5   cselene privacy preserving query retrieval sys...
# 6   highly relevant routing recommendation systems...
# 7   prototipe interoperabilitas learning technolog...
# 8   kompresi citra batik besurek menggunakan discr...
# 9   disaster risk reduction for earthquake using m...
# 10  analysis of language and scientific literacy s...
# 11  the effectiveness of turtle mobile learning ap...
# 12  online expert systems for bamboo identificatio...
# 13  image splicing detection based on demosaicking...
# 14  project based learning to improve scientific l...
# 15  implementasi program literasi sains berbasis i...
# 16  pemetaan zonasi rawan banjir dengan analisis i...
# 17  peningkatan keterampilan guru sd dalam pembuat...
# 18  pengembangan technopreneur produk turunan kopi...
# 19  designing inquiry based expertise sharing mode...
# 20  literasi sains kura kura dengan realitas terta...
# 21  penggunaan aplikasi mobile untuk pembelajaran ...
# 22  peningkatan pendidikan kesiapsiagaan bencana s...
# 23  rancang bangun sistem informasi pemantau trans...
# 24  handling numerical features on dataset using g...
# 25  perancangan framework mobile device management...
# 26  mapping teacher distribution analysis with dig...
# 27  pemberdayaan santri pesantren berwawasan keahl...
# 28  implementasi prinsip animasi straight ahead ac...
# 29  deciding endemic area of dengue fever using si...
# 30  sosialisasi pencegahan iklan berkonten negatif...
# 31  pengembangan keterampilan dan kemampuan guru s...
# 32  implementasi metode ahp topsis dalam sistem pe...
# 33  sistem prediksi masa studi dan predikat kelulu...
#
#                                             tokenized  \
# 0   pengenalan, steganografi, untuk, pengamanan, i...
# 1   the, analysis, of, rank, fusion, techniques, t...
# 2   improving, performance, of, relation, extracti...
# 3   pemanfaatan, citra, penginderaan, jauh, dan, s...
# 4     social, influences, in, recommendation, systems
# 5   cselene, privacy, preserving, query, retrieval...
# 6   highly, relevant, routing, recommendation, sys...
# 7   prototipe, interoperabilitas, learning, techno...
# 8   kompresi, citra, batik, besurek, menggunakan, ...
# 9   disaster, risk, reduction, for, earthquake, us...
# 10  analysis, of, language, and, scientific, liter...
# 11  the, effectiveness, of, turtle, mobile, learni...
# 12  online, expert, systems, for, bamboo, identifi...
# 13  image, splicing, detection, based, on, demosai...
# 14  project, based, learning, to, improve, scienti...
# 15  implementasi, program, literasi, sains, berbas...
# 16  pemetaan, zonasi, rawan, banjir, dengan, anali...
# 17  peningkatan, keterampilan, guru, sd, dalam, pe...
# 18  pengembangan, technopreneur, produk, turunan, ...
# 19  designing, inquiry, based, expertise, sharing,...
# 20  literasi, sains, kura, kura, dengan, realitas,...
# 21  penggunaan, aplikasi, mobile, untuk, pembelaja...
# 22  peningkatan, pendidikan, kesiapsiagaan, bencan...
# 23  rancang, bangun, sistem, informasi, pemantau, ...
# 24  handling, numerical, features, on, dataset, us...
# 25  perancangan, framework, mobile, device, manage...
# 26  mapping, teacher, distribution, analysis, with...
# 27  pemberdayaan, santri, pesantren, berwawasan, k...
# 28  implementasi, prinsip, animasi, straight, ahea...
# 29  deciding, endemic, area, of, dengue, fever, us...
# 30  sosialisasi, pencegahan, iklan, berkonten, neg...
# 31  pengembangan, keterampilan, dan, kemampuan, gu...
# 32  implementasi, metode, ahp, topsis, dalam, sist...
# 33  sistem, prediksi, masa, studi, dan, predikat, ...
#
#                                               removed  \
# 0   pengenalan, steganografi, pengamanan, informas...
# 1   analysis, rank, fusion, techniques, improve, q...
# 2   improving, performance, relation, extraction, ...
# 3   pemanfaatan, citra, penginderaan, sistem, info...
# 4         social, influences, recommendation, systems
# 5   cselene, privacy, preserving, query, retrieval...
# 6   highly, relevant, routing, recommendation, sys...
# 7   prototipe, interoperabilitas, learning, techno...
# 8   kompresi, citra, batik, besurek, discrete, wav...
# 9   disaster, risk, reduction, earthquake, using, ...
# 10  analysis, language, scientific, literacy, skil...
# 11  effectiveness, turtle, mobile, learning, appli...
# 12  online, expert, systems, bamboo, identificatio...
# 13  image, splicing, detection, demosaicking, wave...
# 14  project, learning, improve, scientific, litera...
# 15  implementasi, program, literasi, sains, ict, s...
# 16  pemetaan, zonasi, rawan, banjir, analisis, ind...
# 17  peningkatan, keterampilan, guru, sd, pembuatan...
# 18  pengembangan, technopreneur, produk, turunan, ...
# 19  designing, inquiry, expertise, sharing, model,...
# 20  literasi, sains, kura, kura, realitas, tertamb...
# 21  penggunaan, aplikasi, mobile, pembelajaran, mu...
# 22  peningkatan, pendidikan, kesiapsiagaan, bencan...
# 23  rancang, bangun, sistem, informasi, pemantau, ...
# 24  handling, numerical, features, dataset, using,...
# 25  perancangan, framework, mobile, device, manage...
# 26  mapping, teacher, distribution, analysis, with...
# 27  pemberdayaan, santri, pesantren, berwawasan, k...
# 28  implementasi, prinsip, animasi, straight, ahea...
# 29  deciding, endemic, area, dengue, fever, using,...
# 30  sosialisasi, pencegahan, iklan, berkonten, neg...
# 31  pengembangan, keterampilan, kemampuan, guru, s...
# 32  implementasi, metode, ahp, topsis, sistem, pen...
# 33  sistem, prediksi, studi, predikat, kelulusan, ...
#
#                                               stemmed
# 0   kenal steganografi aman informasi siswa siswi ...
# 1   analysis rank fusion techniques improve query ...
# 2   improving performance relation extraction algo...
# 3   manfaat citra penginderaan sistem informasi ge...
# 4            social influences recommendation systems
# 5   cselene privacy preserving query retrieval sys...
# 6   highly relevant routing recommendation systems...
# 7   prototipe interoperabilitas learning technolog...
# 8   kompresi citra batik besurek discrete wavelet ...
# 9   disaster risk reduction earthquake using mobil...
# 10  analysis language scientific literacy skills t...
# 11  effectiveness turtle mobile learning applicati...
# 12  online expert systems bamboo identification us...
# 13  image splicing detection demosaicking wavelet ...
# 14  project learning improve scientific literacy p...
# 15  implementasi program literasi sains ict sd neg...
# 16  meta zonasi rawan banjir analisis indeks rawan...
# 17  tingkat terampil guru sd buat media animasi ta...
# 18  kembang technopreneur produk turun kopi market...
# 19  designing inquiry expertise sharing model enha...
# 20  literasi sains kura kura realitas tambah siswa...
# 21  guna aplikasi mobile ajar muat lokal potensi alam
# 22  tingkat didik kesiapsiagaan bencana sekolah da...
# 23  rancang bangun sistem informasi pantau transpo...
# 24  handling numerical features dataset using gaus...
# 25  ancang framework mobile device management plat...
# 26  mapping teacher distribution analysis with dig...
# 27  daya santri pesantren wawas ahli terampil mamp...
# 28  implementasi prinsip animasi straight ahead ac...
# 29  deciding endemic area dengue fever using simpl...
# 30  sosialisasi cegah iklan konten negatif smartph...
# 31  kembang terampil mampu guru smkn kota tegal te...
# 32  implementasi metode ahp topsis sistem dukung p...
# 33  sistem prediksi studi predikat kelulus mahasis...

# %%
ms = 3
mp = 10
mnp = 2

data_ms, sheet_ms = read_data(3)
df_ms, stemmed_ms = preprocessing(data, rmlist)
mining(data_ms, stemmed_ms, ms=ms, mp=mp, mnp=mnp)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [43], in <module>
#       5 data_ms, sheet_ms = read_data(3)
#       6 df_ms, stemmed_ms = preprocessing(data, rmlist)
# ----> 7 mining(data_ms, stemmed_ms, ms=ms, mp=mp, mnp=mnp)
#
# Input In [41], in mining(data, stemmed, ms, mp, mnp)
#      61 ps = PrefixSpan(dx)
#      62 print(2)
# ---> 63 pf_results = pd.DataFrame(ps.frequent(2), columns=['freq','sequence'])
#      64 print(3)
#      65 pf_results['sequence'] = [', '.join(n) for n in pf_results['sequence'].values.tolist()]
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:70, in PrefixSpan_frequent(self, minsup, closed, generator, key, bound, filter, callback)
#      67 if key is None:
#      68     key = bound = PrefixSpan.defaultkey
# ---> 70 results = self._mine(frequent_rec)
#      72 return None if callback else results
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/prefixspan.py:19, in PrefixSpan._mine(self, func)
#      15 def _mine(self, func):
#      16     # type: (Callable[[Pattern, Matches], None]) -> Any
#      17     self._results.clear()
# ---> 19     func([], [(i, -1) for i in range(len(self._db))])
#      21     return self._results
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
#     [... skipping similar frames: PrefixSpan_frequent.<locals>.frequent_rec at line 61 (18 times)]
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:49, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      46     if len(patt) == self.maxlen:
#      47         return
# ---> 49 occurs = nextentries(self._db, matches)
#      50 if generator:
#      51     occursstack.append(occurs)
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/extratools/dicttools.py:66, in nextentries(data, entries)
#      65 def nextentries(data: Sequence[Sequence[T]], entries: Entries) -> Mapping[T, Entries]:
# ---> 66     return invertedindex(
#      67         (data[i][lastpos + 1:] for i, lastpos in entries),
#      68         entries
#      69     )
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/extratools/dicttools.py:55, in invertedindex(seqs, entries)
#      52 for k, seq in enumerate(seqs):
#      53     i, lastpos = entries[k] if entries else (k, -1)
# ---> 55     for p, item in enumerate(seq, start=(lastpos + 1)):
#      56         l = index[item]
#      57         if len(l) and l[-1][0] == i:
#
# KeyboardInterrupt:

# %%
dx_ms = [n for n in [a + b + c for a,b,c in zip(stemmed_ms,data_ms['Keyword'].str.split(",").values.tolist(),data_ms['Topik'].str.split(",").values.tolist())]]

# %%
ps_ms = PrefixSpan(dx_ms)

# %%
ps_ms.frequent(2)
# Out:
# [(4, ['area']),
#  (2, ['area', 'earthquake']),
#  (4, [' shrink fitting']),
#  (4, [' shrink fitting', ' finite element method']),
#  (4, [' shrink fitting', ' finite element method', 'Material Durability']),
#  (4, [' shrink fitting', 'Material Durability']),
#  (4, [' finite element method']),
#  (4, [' finite element method', 'Material Durability']),
#  (16, ['Material Durability']),
#  (2, ['daerah']),
#  (2, ['ceramic roller']),
#  (2, ['ceramic roller', ' shrink fitting']),
#  (2, ['ceramic roller', ' shrink fitting', ' finite element method']),
#  (2,
#   ['ceramic roller',
#    ' shrink fitting',
#    ' finite element method',
#    'Material Durability']),
#  (2, ['ceramic roller', ' shrink fitting', 'Material Durability']),
#  (2, ['ceramic roller', ' finite element method']),
#  (2, ['ceramic roller', ' finite element method', 'Material Durability']),
#  (2, ['ceramic roller', 'Material Durability']),
#  (7, ['pengaruh']),
#  (4, ['pengaruh', 'beton']),
#  (2, ['pengaruh', 'beton', 'kuat']),
#  (2, ['pengaruh', 'beton', 'kuat', 'beton']),
#  (2, ['pengaruh', 'beton', 'kuat', 'beton', 'Material Durability']),
#  (2, ['pengaruh', 'beton', 'kuat', 'Material Durability']),
#  (2, ['pengaruh', 'beton', 'beton']),
#  (2, ['pengaruh', 'beton', 'beton', 'Material Durability']),
#  (3, ['pengaruh', 'beton', 'Material Durability']),
#  (5, ['pengaruh', 'kuat']),
#  (3, ['pengaruh', 'kuat', 'tekan']),
#  (3, ['pengaruh', 'kuat', 'tekan', 'beton']),
#  (2, ['pengaruh', 'kuat', 'tekan', 'beton', 'Material Durability']),
#  (2, ['pengaruh', 'kuat', 'tekan', 'Material Durability']),
#  (4, ['pengaruh', 'kuat', 'beton']),
#  (3, ['pengaruh', 'kuat', 'beton', 'Material Durability']),
#  (3, ['pengaruh', 'kuat', 'Material Durability']),
#  (3, ['pengaruh', 'tekan']),
#  (3, ['pengaruh', 'tekan', 'beton']),
#  (2, ['pengaruh', 'tekan', 'beton', 'Material Durability']),
#  (2, ['pengaruh', 'tekan', 'Material Durability']),
#  (4, ['pengaruh', 'Material Durability']),
#  (2, ['pengaruh', 'gradasi']),
#  (2, ['pengaruh', 'gradasi', 'pasir']),
#  (2, ['pengaruh', 'gradasi', 'pasir', 'kuat']),
#  (2, ['pengaruh', 'gradasi', 'kuat']),
#  (2, ['pengaruh', 'pasir']),
#  (2, ['pengaruh', 'pasir', 'kuat']),
#  (3, ['pengaruh', 'kota']),
#  (2, ['pengaruh', 'kota', 'Renewable Energy']),
#  (2, ['pengaruh', 'Renewable Energy']),
#  (2, ['pengaruh', 'suhu']),
#  (2, ['pengaruh', 'suhu', 'bakar']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'bangungan']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'bangungan', 'pasar']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'bangungan', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'bangungan', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'struktur',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'struktur', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'pasar']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'pasar', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'pasar', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'bangungan',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'elemen',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'elemen', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'pasar']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'bangungan',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'struktur',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'struktur', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bakar',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bakar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'pasar']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'struktur',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'struktur', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'elemen',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'modern']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'elemen', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'struktur', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'modern']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'struktur', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'suhu',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'modern']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'pasar', 'kota']),
#  (2, ['pengaruh', 'suhu', 'tradisional']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'suhu', 'modern']),
#  (2, ['pengaruh', 'suhu', 'modern', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'modern', 'kota']),
#  (2, ['pengaruh', 'suhu', 'ptm']),
#  (2, ['pengaruh', 'suhu', 'ptm', 'kota']),
#  (2, ['pengaruh', 'suhu', 'kota']),
#  (2, ['pengaruh', 'bakar']),
#  (2, ['pengaruh', 'bakar', 'elemen']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'pasar']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2,
#   ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'modern']),
#  (2,
#   ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'bakar', 'elemen', 'struktur', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'bakar',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
# ...
#    'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh', 'bakar', 'bangungan', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'modern']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'pasar', 'kota']),
#  (2, ['pengaruh', 'bakar', 'tradisional']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'bakar', 'modern']),
#  (2, ['pengaruh', 'bakar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'modern', 'kota']),
#  (2, ['pengaruh', 'bakar', 'ptm']),
#  (2, ['pengaruh', 'bakar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'bakar', 'kota']),
#  (2, ['pengaruh', 'elemen']),
#  (2, ['pengaruh', 'elemen', 'struktur']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'tradisional']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2,
#   ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'struktur',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'modern']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'elemen', 'struktur', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'modern']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'struktur', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'elemen',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh', 'elemen', 'bangungan', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'modern']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'pasar', 'kota']),
#  (2, ['pengaruh', 'elemen', 'tradisional']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'elemen', 'modern']),
#  (2, ['pengaruh', 'elemen', 'modern', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'modern', 'kota']),
#  (2, ['pengaruh', 'elemen', 'ptm']),
#  (2, ['pengaruh', 'elemen', 'ptm', 'kota']),
#  (2, ['pengaruh', 'elemen', 'kota']),
#  (2, ['pengaruh', 'struktur']),
#  (2, ['pengaruh', 'struktur', 'bangungan']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'tradisional', 'modern']),
#  (2,
#   ['pengaruh',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm']),
#  (2,
#   ['pengaruh',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2,
#   ['pengaruh',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'modern',
#    'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'tradisional', 'ptm']),
#  (2,
#   ['pengaruh',
#    'struktur',
#    'bangungan',
#    'pasar',
#    'tradisional',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'modern']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'pasar', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh',
#    'struktur',
#    'bangungan',
#    'tradisional',
#    'modern',
#    'ptm',
#    'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'modern']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'modern', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'bangungan', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'modern', 'ptm']),
#  (2,
#   ['pengaruh', 'struktur', 'pasar', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'tradisional', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'modern']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'modern', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'pasar', 'kota']),
#  (2, ['pengaruh', 'struktur', 'tradisional']),
#  (2, ['pengaruh', 'struktur', 'tradisional', 'modern']),
#  (2, ['pengaruh', 'struktur', 'tradisional', 'modern', 'ptm']),
#  (2, ['pengaruh', 'struktur', 'tradisional', 'modern', 'ptm', 'kota']),
#  (2, ['pengaruh', 'struktur', 'tradisional', 'modern', 'kota']),
#  (2, ['pengaruh', 'struktur', 'tradisional', 'ptm']),
#  ...]

# %%
ms = 2
mp = 10
mnp = 2

pf_results_ms = pd.DataFrame(ps_ms.frequent(ms), columns=['freq','sequence'])
print("first")
pf_results_ms['sequence'] = [', '.join(n) for n in pf_results_ms['sequence'].values.tolist()]
print("second")
pf_results_ms = pf_results_ms[[len(n)<=mp for n in pf_results_ms['sequence'].str.split(",").values.tolist()]]
print("third")
pf_results_ms = pf_results_ms[[len(n)>=mnp for n in pf_results_ms['sequence'].str.split(",").values.tolist()]].sort_values(by='freq',ascending=False).reset_index(drop=True)
# Out:
# first
# second
# third

# %%
pf_results_ms
# Out:
#       freq                                           sequence
# 0        7                            liquefaction, potential
# 1        5                                     pengaruh, kuat
# 2        5                                   ground, response
# 3        4                shrink fitting, Material Durability
# 4        4                                        kuat, tekan
# ...    ...                                                ...
# 2450     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2451     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2452     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2453     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2454     2                       trombone coil, Refrigeration
#
# [2455 rows x 2 columns]

# %%
pf= mining(data_ms, stemmed_ms, ms=ms, mp=mp, mnp=mnp)

# %%
pf
# Out:
#       freq                                           sequence
# 0        7                            liquefaction, potential
# 1        5                                     pengaruh, kuat
# 2        5                                   ground, response
# 3        4                shrink fitting, Material Durability
# 4        4                                        kuat, tekan
# ...    ...                                                ...
# 2450     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2451     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2452     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2453     2  pengaruh, elemen, struktur, bangungan, pasar, ...
# 2454     2                       trombone coil, Refrigeration
#
# [2455 rows x 2 columns]

# %%
run(3,rmlist)
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [35], in <module>
# ----> 1 run(3,rmlist)
#
# Input In [33], in run(x, listtoberemoved, ms, mp, mnp)
#      72 data, sheet= read_data(x)
#      73 df, stemmed = preprocessing(data, listtoberemoved)
# ---> 74 pf= mining(data, stemmed, ms=ms, mp=mp, mnp=mnp)
#      75 return sheet, pf,data, df
#
# Input In [33], in mining(data, stemmed, ms, mp, mnp)
#      61 ps = PrefixSpan(dx)
#      62 print(2)
# ---> 63 pf_results = pd.DataFrame(ps.frequent(ms), columns=['freq','sequence'])
#      64 print(3)
#      65 pf_results['sequence'] = [', '.join(n) for n in pf_results['sequence'].values.tolist()]
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:70, in PrefixSpan_frequent(self, minsup, closed, generator, key, bound, filter, callback)
#      67 if key is None:
#      68     key = bound = PrefixSpan.defaultkey
# ---> 70 results = self._mine(frequent_rec)
#      72 return None if callback else results
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/prefixspan.py:19, in PrefixSpan._mine(self, func)
#      15 def _mine(self, func):
#      16     # type: (Callable[[Pattern, Matches], None]) -> Any
#      17     self._results.clear()
# ---> 19     func([], [(i, -1) for i in range(len(self._db))])
#      21     return self._results
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
#     [... skipping similar frames: PrefixSpan_frequent.<locals>.frequent_rec at line 61 (8 times)]
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:61, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      55     if canpass(bound(newpatt, newmatches)) or (
#      56             closed and canclosedprune(self._db, newpatt, newmatches) or
#      57             generator and cangeneratorprune(self._db, newpatt, newmatches, occursstack)
#      58         ):
#      59         continue
# ---> 61     frequent_rec(newpatt, newmatches)
#      63 if generator:
#      64     occursstack.pop()
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:44, in PrefixSpan_frequent.<locals>.frequent_rec(patt, matches)
#      41 def frequent_rec(patt, matches):
#      42     # type: (Pattern, Matches) -> None
#      43     if len(patt) >= self.minlen:
# ---> 44         verify(patt, matches)
#      46         if len(patt) == self.maxlen:
#      47             return
#
# File ~/.local/share/virtualenvs/2021-098-text-information-retrieval-2iCbVj09/lib/python3.9/site-packages/prefixspan/frequent.py:35, in PrefixSpan_frequent.<locals>.verify(patt, matches)
#      29     return
#      31 if (filter is None or filter(patt, matches)) and (
#      32         (not closed or isclosed(self._db, patt, matches)) and
#      33         (not generator or isgenerator(self._db, patt, matches, occursstack))
#      34     ):
# ---> 35     if callback:
#      36         callback(patt, matches)
#      37     else:
#
# KeyboardInterrupt:
